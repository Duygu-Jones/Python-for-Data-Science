# %% [markdown]
# ## Random Module

# %%
import random   # import ifadesi modulu/classi ice aktarmak icin kullanilir

# %%
random.random() #0 dahil, 1 haric araliginda sayilar uretir
# Out:
# 0.41975381115092303

# %%
random.seed(35)
random.random()
# Out:
# 0.5486946056438222

# %%
random.seed(27) #belli bir sabite gore ayni degerleri rassal olarak uretilir
random.random()
# Out:
# 0.6484972199788831

# %%
random.sample(range(100),5) # 100'e kadar olan sayilardan rastgele 5 tanesini getirdi
# Out:
# [89, 35, 36, 25, 9]

# %%
random.randint(1,6)
# Out:
# 5

# %%
random.sample(range(1,10),4)    #range 1 ile 10 arasinda sayilar uretir, Sample ise bu sayilardan istenilen adet kadar 4 sayi secer
# Out:
# [5, 6, 3, 7]

# %%
y = True
aklımdaki_sayı = random.randint(1,100)
while y:
    tahmin = int(input("1 ile 100 arasında bir sayı tahmin edin."))
    if aklımdaki_sayı < tahmin:
        print(f"Girdiğiniz sayı : {tahmin}. Tahminini azalt")
    elif aklımdaki_sayı > tahmin:
        print(f"Girdiğiniz sayı : {tahmin}. Tahminini arttır")
    else:
        print(f"Girdiğiniz sayı : {tahmin}. Doğru bildiniz. Tebrikler. ")
        y = False
# Out:
# Girdiğiniz sayı : 90. Tahminini azalt
# Girdiğiniz sayı : 78. Tahminini azalt
# Girdiğiniz sayı : 78. Tahminini azalt
# Girdiğiniz sayı : 89. Tahminini azalt
# Girdiğiniz sayı : 50. Tahminini arttır
# Girdiğiniz sayı : 66. Tahminini azalt
# Girdiğiniz sayı : 65. Tahminini azalt
# Girdiğiniz sayı : 60. Tahminini azalt
# Girdiğiniz sayı : 61. Tahminini azalt
# Girdiğiniz sayı : 58. Tahminini azalt
# Girdiğiniz sayı : 59. Tahminini azalt
# Girdiğiniz sayı : 56. Tahminini azalt
# Girdiğiniz sayı : 55. Tahminini azalt
# Girdiğiniz sayı : 50. Tahminini arttır
# Girdiğiniz sayı : 52. Doğru bildiniz. Tebrikler.

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %% [markdown]
# # Break - Continue

# %%
aklımdaki_sayı = random.randint(1,100)

while True:

    tahmin = int(input("1 ile 100 arasında bir sayı tahmin edin."))

    if aklımdaki_sayı < tahmin:
        print(f"Girdiğiniz sayı : {tahmin}. Tahminini azalt")

    elif aklımdaki_sayı > tahmin:
        print(f"Girdiğiniz sayı : {tahmin}. Tahminini arttır")

    else:
        print(f"Girdiğiniz sayı : {tahmin}. Doğru bildiniz. Tebrikler. ")
    
        break

# %%
import time
aklımdaki_sayı = random.randint(1,100)

time.sleep(2)

sayaç = 0

while True:

    tahmin = int(input("1 ile 100 arasında bir sayı tahmin edin."))

    sayaç += 1

    time.sleep(2)

    if aklımdaki_sayı < tahmin:
        print(f"Girdiğiniz sayı : {tahmin}. Tahminini azalt")

    elif aklımdaki_sayı > tahmin:
        print(f"Girdiğiniz sayı : {tahmin}. Tahminini arttır")

    else:
        print(f"Girdiğiniz sayı : {tahmin}. Doğru bildiniz. Tebrikler. ")
        break

    time.sleep(2)

    if sayaç == 5:
        print(f"5 hakkın bitti. sayı {aklımdaki_sayı}")
        break

# %%
import time
help(time.sleep)
# Out:
# Help on built-in function sleep in module time:
#
# sleep(...)
#     sleep(seconds)
#
#     Delay execution for a given number of seconds.  The argument may be
#     a floating point number for subsecond precision.

# %%
liste = [1, 2, 3, 4, "Techpro", 5, 6, 7] # sırayla int değerleri toplayın. str ifadeye denk gelince kod sonlansın

x = 0

toplam = 0          # toplamada etkisiz eleman- bos sepet gibi dusunebiliriz, sonucu burada biriktirecek

while x < len(liste):

    if type(liste[x]) == int:
        toplam += liste[x]

    elif type(liste[x]) == str:
        break

    x += 1

print(toplam)
# Out:
# 10

# %%
liste = [1, 2, 3, 4, "Techpro", 5, 6, 7] # sırayla int değerleri toplayın. str ifadeye denk gelince o ifedayi atlayın ve devam edin


x = 0

toplam = 0

while x < len(liste):

    if type(liste[x]) == int:
        toplam += liste[x]

    elif type(liste[x]) == str:
        x += 1                  # bulundugu index'e 1 ekle ve EN BASA DON!!!
        continue

    x += 1

print(toplam)                   # en son sonucu yazdirir
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 15
#      11         toplam += liste[x]
#      13     elif type(liste[x]) == str:
# ---> 15         continue
#      17     x += 1
#      19 print(toplam)
#
# KeyboardInterrupt:

# %% [markdown]
# # min() - max() fonks

# %%
list1= [1,3,54,56,7,8,456,86,21,-8]

# %%
min(list1)
# Out:
# -8

# %%
max(list1)
# Out:
# 456

# %%
tuple1= (1,2,3,4,5,6)

# %%
min(tuple1)
# Out:
# 1

# %%
max(tuple1)
# Out:
# 6

# %%
min(["techpro", "aylin","irem"])
# Out:
# 'aylin'

# %%
min(["techpro", "aylin","irem"], 15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 min(["techpro", "aylin","irem"], 15)
#
# TypeError: '<' not supported between instances of 'int' and 'list'

# %%
#ODEV: 
liste_1 = [4,5,6,9,85,23,65,47,32,91] 

#listenin en küçük ve en büyük elemanını min ve max fpnksiyonu kullanmadan bulun. sort fonk da kullanmayın.

# %%
liste_1 = [4, 5, 6, 9, 85, 23, 65, 47, 32, 91]

# define the first element of the list as the min_num and max_num
min_num = liste_1[0]   
max_num = liste_1[0]

i = 1
while i < len(liste_1):
    
    if liste_1[i] < min_num:   # index 1 ile baslayip 0.index ile karsilastirir
        min_num = liste_1[i]   # min_num degiskenine yeniden deger atamasi yapilir
        
    if liste_1[i] > max_num:
        max_num = liste_1[i]
    i += 1

print("min number:", min_num, "\nmax number:", max_num)
# Out:
# min number: 4
# max number: 91
