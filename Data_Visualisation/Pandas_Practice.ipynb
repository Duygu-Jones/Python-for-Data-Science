# %% [markdown]
# # <p style="background-color:dodgerblue;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Pandas Practice</b></p>
#
# <p style="text-align: right;"><font color='Magenta'> <b>Duygu Jones</b><font color='black'><p>
#
# <p style="text-align: right;"><font color='dodgerblue'> <b>Data_Science  | 2024</b><font color='orange'><p>
#
# <b>Follow me </b>[Linkedin](https://www.linkedin.com/in/duygujones/) | [GitHub](https://github.com/Duygu-Jones) | [Kaggle](https://www.kaggle.com/duygujones) | [Tableau](https://public.tableau.com/app/profile/duygu.jones/vizzes) | [Source]()

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## After reading the dataset, assign it named "df"

# %%
df = pd.read_csv("data.csv", encoding="unicode_escape")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Check the Head of the DataFrame

# %% [markdown]
# **Her hücrede belirtilen görev uyarınca altında yer alan çıktıya ulaşmaya çalışacaksınız.**

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Find out the describe and info attributes of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.describe(include='all').T
# Out:
#                 count unique                                 top    freq  \
# InvoiceNo      541909  25900                              573585    1114
# StockCode      541909   4070                              85123A    2313
# Description    540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# Quantity     541909.0    NaN                                 NaN     NaN
# InvoiceDate    541909  23260                    10/31/2011 14:41    1114
# UnitPrice    541909.0    NaN                                 NaN     NaN
# CustomerID   406829.0    NaN                                 NaN     NaN
# Country        541909     38                      United Kingdom  495478
#
#                     mean          std       min      25%      50%      75%  \
# InvoiceNo            NaN          NaN       NaN      NaN      NaN      NaN
# StockCode            NaN          NaN       NaN      NaN      NaN      NaN
# Description          NaN          NaN       NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Find out the shape and size info of the dataset

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.size
# Out:
# 4335272

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Find out the types values of the columns

# %%
dtype = df.dtypes
dtype
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Find out the non-null counts of the columns

# %%
notnull = df.notnull().sum()
notnull
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Find out the null counts of the columns

# %%
isnull = df.isnull().sum().sort_values(ascending=False)
isnull
# Out:
# CustomerID     135080
# Description      1454
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Find out the unique counts of the columns

# %%
unique = df.nunique().sort_values(ascending=False)
unique
# Out:
# InvoiceNo      25900
# InvoiceDate    23260
# CustomerID      4372
# Description     4223
# StockCode       4070
# UnitPrice       1630
# Quantity         722
# Country           38
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.Country.unique() # series donderdigi icin unique() kullanilabilir
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# ## Combine the dataframes you created in questions 5-6-7-8

# %%
my_list = [dtype, notnull, isnull, unique]

new_df = pd.concat(my_list, axis = 1)

new_df.columns = ["dtype", "notnull", "isnull", "unique"]

new_df

# %%
result = df.apply(lambda col: pd.Series([col.dtype, col.notnull().sum(), col.isnull().sum(), col.nunique()], 
                                        index=['dtype', 'notnull', 'isnull', 'unique']))
print(result.T)
# Out:
#                dtype notnull  isnull unique
# InvoiceNo     object  541909       0  25900
# StockCode     object  541909       0   4070
# Description   object  540455    1454   4223
# Quantity       int64  541909       0    722
# InvoiceDate   object  541909       0  23260
# UnitPrice    float64  541909       0   1630
# CustomerID   float64  406829  135080   4372
# Country       object  541909       0     38

# %%
result = pd.DataFrame({
    'dtype': df.dtypes,
    'notnull': df.notnull().sum(),
    'isnull': df.isnull().sum(),
    'unique': df.nunique()
})

print(result)
# Out:
#                dtype  notnull  isnull  unique
# InvoiceNo     object   541909       0   25900
# StockCode     object   541909       0    4070
# Description   object   540455    1454    4223
# Quantity       int64   541909       0     722
# InvoiceDate   object   541909       0   23260
# UnitPrice    float64   541909       0    1630
# CustomerID   float64   406829  135080    4372
# Country       object   541909       0      38

# %%
result = pd.concat([df.dtypes, df.notnull().sum(), df.isnull().sum(), df.nunique()], axis=1)
result.columns = ['dtype', 'notnull', 'isnull', 'unique']
print(result)
# Out:
#                dtype  notnull  isnull  unique
# InvoiceNo     object   541909       0   25900
# StockCode     object   541909       0    4070
# Description   object   540455    1454    4223
# Quantity       int64   541909       0     722
# InvoiceDate   object   541909       0   23260
# UnitPrice    float64   541909       0    1630
# CustomerID   float64   406829  135080    4372
# Country       object   541909       0      38

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Lowercase all column names

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       invoicedate  unitprice  customerid         country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## What is the average of Product sold and the average price of Product per unit?

# %%
df[['quantity', 'unitprice']].mean()
# Out:
# quantity     9.552250
# unitprice    4.611114
# dtype: float64

# %%
df.agg({"unitprice": "mean","quantity": "mean" })
# Out:
# unitprice    4.611114
# quantity     9.552250
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## What are the highest and lowest purchase prices?

# %%
df.agg({"unitprice": "min", "unitprice": "max" })
# Out:
# unitprice    38970.0
# dtype: float64

# %%
print(df.unitprice.max())
print(df.unitprice.min())
# Out:
# 38970.0
# -11062.06

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## List the country names and number of their records belongs to each country

# %%
df.country.value_counts()
# Out:
# country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How many records are there in the Germany?

# %%
df[df.country == 'Germany'].count()
# Out:
# invoiceno      9495
# stockcode      9495
# description    9495
# quantity       9495
# invoicedate    9495
# unitprice      9495
# customerid     9495
# country        9495
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Create a column named "Total" which shows the total amount of spend using UnitPrice and Quantity

# %%
df['total'] = df.unitprice * df.quantity
df
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             invoicedate  unitprice  customerid         country  total
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Show total spending amount according to the Countries and their percentages.

# %%
df.groupby('country')['total'].sum().sort_values(ascending=False)
# Out:
# country
# United Kingdom          8187806.364
# Netherlands              284661.540
# EIRE                     263276.820
# Germany                  221698.210
# France                   197403.900
# Australia                137077.270
# Switzerland               56385.350
# Spain                     54774.580
# Belgium                   40910.960
# Sweden                    36595.910
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  29367.020
# Finland                   22326.740
# Channel Islands           20086.290
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12946.290
# Austria                   10154.320
# Hong Kong                 10117.040
# Singapore                  9120.390
# Israel                     7907.820
# Poland                     7213.140
# Unspecified                4749.790
# Greece                     4710.520
# Iceland                    4310.000
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.groupby('country')['total'].sum().sort_values(ascending=False) / df.total.sum() * 100
# Out:
# country
# United Kingdom          83.996903
# Netherlands              2.920280
# EIRE                     2.700899
# Germany                  2.274353
# France                   2.025123
# Australia                1.406246
# Switzerland              0.578445
# Spain                    0.561920
# Belgium                  0.419697
# Sweden                   0.375429
# Japan                    0.362552
# Norway                   0.360734
# Portugal                 0.301270
# Finland                  0.229045
# Channel Islands          0.206061
# Denmark                  0.192538
# Italy                    0.173276
# Cyprus                   0.132813
# Austria                  0.104171
# Hong Kong                0.103788
# Singapore                0.093564
# Israel                   0.081125
# Poland                   0.073998
# Unspecified              0.048727
# Greece                   0.048324
# Iceland                  0.044215
# Canada                   0.037613
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Which Country spend least?

# %%
df.groupby('country')['total'].sum().sort_values(ascending=True).head(1)
# Out:
# country
# Saudi Arabia    131.17
# Name: total, dtype: float64

# %%
df.groupby('country')['total'].sum().sort_values(ascending=True).iloc[:1]
# Out:
# country
# Saudi Arabia    131.17
# Name: total, dtype: float64

# %%
df.groupby('country')['total'].sum().sort_values(ascending=True).nsmallest(1)
# Out:
# country
# Saudi Arabia    131.17
# Name: total, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Which Country spend most?

# %%
df.groupby('country')['total'].sum().sort_values(ascending=True).tail(1)
# Out:
# country
# United Kingdom    8187806.364
# Name: total, dtype: float64

# %%
df.groupby('country')['total'].sum().sort_values(ascending=False).iloc[:1]
# Out:
# country
# United Kingdom    8187806.364
# Name: total, dtype: float64

# %%
df.groupby('country')['total'].sum().nlargest(1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Calculate the average of spending according to country with apply function and create a new feature named "Average_Spend"

# %%
df.groupby('country')['total'].transform(np.mean)
# Out:
# 0         16.525065
# 1         16.525065
# 2         16.525065
# 3         16.525065
# 4         16.525065
#             ...
# 541904    23.069288
# 541905    23.069288
# 541906    23.069288
# 541907    23.069288
# 541908    23.069288
# Name: total, Length: 541909, dtype: float64

# %%
df.groupby('country')['total'].apply(np.mean)
# Out:
# country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['average_spend']= df.groupby('country')['total'].transform(np.mean)
df.sample(20)
# Out:
#        invoiceno stockcode                          description  quantity  \
# 39222     539631     22671       FRENCH LAUNDRY SIGN BLUE METAL         1
# 44324     540168     22241          GARLAND WOODEN HAPPY EASTER         6
# 410140    572092     16045           POPART WOODEN PENCILS ASST       100
# 130644    547498    84997D      CHILDRENS CUTLERY POLKADOT PINK         1
# 234568    557569     22636   CHILDS BREAKFAST SET CIRCUS PARADE         4
# 452760    575384     22736          RIBBON REEL MAKING SNOWMEN         10
# 143876    548714     21398             RED POLKADOT COFFEE  MUG         5
# 425490    573326     22661      CHARLOTTE BAG DOLLY GIRL DESIGN        10
# 160322    550458     22716                   CARD CIRCUS PARADE         3
# 479630    577173     23202               JUMBO BAG VINTAGE LEAF        20
# 155119    549966     22245         HOOK, 1 HANGER ,MAGIC GARDEN        12
# 349531    567507     22807         SET OF 6 T-LIGHTS TOADSTOOLS         1
# ...

# %%
df.iloc[30:100]
# Out:
#    invoiceno stockcode                          description  quantity  \
# 30    536370     21883                     STARS GIFT TAPE         24
# 31    536370     10002          INFLATABLE POLITICAL GLOBE         48
# 32    536370     21791   VINTAGE HEADS AND TAILS CARD GAME         24
# 33    536370     21035      SET/2 RED RETROSPOT TEA TOWELS         18
# 34    536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND         24
# ..       ...       ...                                  ...       ...
# 95    536378     22352    LUNCH BOX WITH CUTLERY RETROSPOT          6
# 96    536378     21212      PACK OF 72 RETROSPOT CAKE CASES       120
# 97    536378     21975       PACK OF 60 DINOSAUR CAKE CASES        24
# 98    536378     21977   PACK OF 60 PINK PAISLEY CAKE CASES        24
# 99    536378     84991          60 TEATIME FAIRY CAKE CASES        24
#
#        invoicedate  unitprice  customerid         country  total  \
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Calculate average, min, max of spending according to country with agg() function and create new features named "Max_Spend", "Min_Spend" and "Mean_Spend"

# %%
df.groupby('country')['total'].agg([min,max,'mean'])
# Out:
#                             min        max        mean
# country
# Australia               -425.00    1718.40  108.877895
# Austria                  -21.25     360.00   25.322494
# Bahrain                 -205.74     205.74   28.863158
# Belgium                  -19.95     165.00   19.773301
# Brazil                    15.00     175.20   35.737500
# Canada                     2.50     550.94   24.280662
# Channel Islands         -293.00     408.00   26.499063
# Cyprus                  -320.69     320.69   20.813971
# Czech Republic           -35.76      70.80   23.590667
# Denmark                  -59.80     428.40   48.247147
# EIRE                   -1917.00    2365.20   32.122599
# European Community        -8.50      60.00   21.176230
# Finland                  -80.00     551.20   32.124806
# France                 -8322.12    4161.06   23.069288
# Germany                 -599.50     876.00   23.348943
# Greece                   -50.00     175.20   32.263836
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['min_spend']=df.groupby('country').total.transform(min)
df['max_spend']=df.groupby('country').total.transform(max)
df
# Out:
#        invoiceno stockcode                          description  quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             invoicedate  unitprice  customerid         country  total  \
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## What is the max Total spending in whole dataset and show all records of that spending?

# %%
df.total.max()
# Out:
# 168469.6

# %%
df[df.total == df.total.max()]
# Out:
#        invoiceno stockcode                  description  quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            invoicedate  unitprice  customerid         country     total  \
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6
#
#         average_spend  min_spend  max_spend
# 540421      16.525065  -168469.6   168469.6

# %%
df.nlargest(1, "total") # slicing
# Out:
#        invoiceno stockcode                  description  quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            invoicedate  unitprice  customerid         country     total  \
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6
#
#         average_spend  min_spend  max_spend
# 540421      16.525065  -168469.6   168469.6

# %%
df.nlargest(5, "total") #[0,5).indexler
# Out:
#        invoiceno  stockcode                     description  quantity  \
# 540421    581483      23843     PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431      23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 222680    556444      22502  PICNIC BASKET WICKER 60 PIECES        60
# 15017     537632  AMAZONFEE                      AMAZON FEE         1
# 299982   A563185          B                 Adjust bad debt         1
#
#             invoicedate  unitprice  customerid         country      total  \
# 540421   12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.60
# 61619   1/18/2011 10:01       1.04     12346.0  United Kingdom   77183.60
# 222680  6/10/2011 15:28     649.50     15098.0  United Kingdom   38970.00
# 15017   12/7/2010 15:08   13541.33         NaN  United Kingdom   13541.33
# 299982  8/12/2011 14:50   11062.06         NaN  United Kingdom   11062.06
#
#         average_spend  min_spend  max_spend
# 540421      16.525065  -168469.6   168469.6
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How many people who live in France spend more than average Total?

# %%
df[df.total > df.total.mean()]
# Out:
#        invoiceno stockcode                          description  quantity  \
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# ...          ...       ...                                  ...       ...
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
# 541895    581587     22556       PLASTERS IN TIN CIRCUS PARADE         12
# 541896    581587     22555            PLASTERS IN TIN STRONGMAN        12
# 541902    581587     22629                  SPACEBOY LUNCH BOX         12
#
#             invoicedate  unitprice  customerid         country  total  \
# ...

# %%
df[(df.total > df.total.mean()) & ((df.country == "France")) ]
# Out:
#        invoiceno stockcode                         description  quantity  \
# 26        536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727           ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726          ALARM CLOCK BAKELIKE GREEN        12
# 31        536370     10002         INFLATABLE POLITICAL GLOBE         48
# 32        536370     21791  VINTAGE HEADS AND TAILS CARD GAME         24
# ...          ...       ...                                 ...       ...
# 537462    581279      POST                             POSTAGE         3
# 541894    581587     22631            CIRCUS PARADE LUNCH BOX         12
# 541895    581587     22556      PLASTERS IN TIN CIRCUS PARADE         12
# 541896    581587     22555           PLASTERS IN TIN STRONGMAN        12
# 541902    581587     22629                 SPACEBOY LUNCH BOX         12
#
#             invoicedate  unitprice  customerid country  total  average_spend  \
# ...

# %%
df[(df.total > df.total.mean()) & ((df.country == "France")) ].shape[0]
# Out:
# 3397

# %%
df[(df.total > df.total.mean()) & ((df['country'] == 'France'))].count()
# Out:
# invoiceno        3397
# stockcode        3397
# description      3397
# quantity         3397
# invoicedate      3397
# unitprice        3397
# customerid       3383
# country          3397
# total            3397
# average_spend    3397
# min_spend        3397
# max_spend        3397
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Convert datatype of "InvoiceDate" to datetime and assign it to new column name "InvoiceDate2"

# %%
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       invoicedate  unitprice  customerid         country  total  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
#
#    average_spend  min_spend  max_spend
# 0      16.525065  -168469.6   168469.6
# 1      16.525065  -168469.6   168469.6
# 2      16.525065  -168469.6   168469.6
# ...

# %%
pd.to_datetime(df["invoicedate"])
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoicedate, Length: 541909, dtype: datetime64[ns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df["invoice_date2"] = pd.to_datetime(df["invoicedate"])
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       invoicedate  unitprice  customerid         country  total  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
#
#    average_spend  min_spend  max_spend       invoice_date2
# 0      16.525065  -168469.6   168469.6 2010-12-01 08:26:00
# ...

# %% [markdown]
# ## Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date

# %%
df["date"] = df['invoice_date2'].dt.to_period("D") # sadece arih (Date) leri getirir
df.head(3)
# Out:
#   invoiceno stockcode                         description  quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#       invoicedate  unitprice  customerid         country  total  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
#
#    average_spend  min_spend  max_spend       invoice_date2        date
# 0      16.525065  -168469.6   168469.6 2010-12-01 08:26:00  2010-12-01
# 1      16.525065  -168469.6   168469.6 2010-12-01 08:26:00  2010-12-01
# 2      16.525065  -168469.6   168469.6 2010-12-01 08:26:00  2010-12-01

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Drop "InvoiceDate2" and "InvoiceDate" columns permanently

# %%
df.drop(["invoicedate", "invoice_date2"], axis = 1, inplace=True)

# %%
df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    unitprice  customerid         country  total  average_spend  min_spend  \
# 0       2.55     17850.0  United Kingdom  15.30      16.525065  -168469.6
# 1       3.39     17850.0  United Kingdom  20.34      16.525065  -168469.6
# 2       2.75     17850.0  United Kingdom  22.00      16.525065  -168469.6
# 3       3.39     17850.0  United Kingdom  20.34      16.525065  -168469.6
# 4       3.39     17850.0  United Kingdom  20.34      16.525065  -168469.6
#
#    max_spend        date
# 0   168469.6  2010-12-01
# 1   168469.6  2010-12-01
# 2   168469.6  2010-12-01
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Remove A, B, G and E characters at the first 5 rows of "StockCode" in ecom dataframe with a string method

# %%
df.loc[:4, "stockcode"]
# Out:
# 0    85123A
# 1     71053
# 2    84406B
# 3    84029G
# 4    84029E
# Name: stockcode, dtype: object

# %%
df.loc[:4, "stockcode"].str.replace('[ABGE]','', regex=True)
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: stockcode, dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.loc[:4, "stockcode"].str.strip('[ABGE]') #sadece bastan ve sondan siler
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: stockcode, dtype: object

# %% [markdown]
# ## Take only "Total" and "date" columns with loc and craete a new df named df2

# %%
df2 = df.loc[:, ["total", "date"]]
df2
# Out:
#         total        date
# 0       15.30  2010-12-01
# 1       20.34  2010-12-01
# 2       22.00  2010-12-01
# 3       20.34  2010-12-01
# 4       20.34  2010-12-01
# ...       ...         ...
# 541904  10.20  2011-12-09
# 541905  12.60  2011-12-09
# 541906  16.60  2011-12-09
# 541907  16.60  2011-12-09
# 541908  14.85  2011-12-09
#
# [541909 rows x 2 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Take only "InvoiceNo", "CustomerID", "Total" columns with iloc and craete a new df named df3

# %%
list(df.columns).index("total")
# Out:
# 7

# %%
df3 = df.iloc[:, [0,5,7]]
df3
# Out:
#        invoiceno  customerid  total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 541904    581587     12680.0  10.20
# 541905    581587     12680.0  12.60
# 541906    581587     12680.0  16.60
# 541907    581587     12680.0  16.60
# 541908    581587     12680.0  14.85
#
# [541909 rows x 3 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Combine "df2" and "df3" with concat() method

# %%
pd.concat([df2,df3], axis = 1)
# Out:
#         total        date invoiceno  customerid  total
# 0       15.30  2010-12-01    536365     17850.0  15.30
# 1       20.34  2010-12-01    536365     17850.0  20.34
# 2       22.00  2010-12-01    536365     17850.0  22.00
# 3       20.34  2010-12-01    536365     17850.0  20.34
# 4       20.34  2010-12-01    536365     17850.0  20.34
# ...       ...         ...       ...         ...    ...
# 541904  10.20  2011-12-09    581587     12680.0  10.20
# 541905  12.60  2011-12-09    581587     12680.0  12.60
# 541906  16.60  2011-12-09    581587     12680.0  16.60
# 541907  16.60  2011-12-09    581587     12680.0  16.60
# 541908  14.85  2011-12-09    581587     12680.0  14.85
#
# [541909 rows x 5 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Combine "df2" and "df3" with join() method

# %%
df2.join(df3, lsuffix="_left", rsuffix= "_right")
# Out:
#         total_left        date invoiceno  customerid  total_right
# 0            15.30  2010-12-01    536365     17850.0        15.30
# 1            20.34  2010-12-01    536365     17850.0        20.34
# 2            22.00  2010-12-01    536365     17850.0        22.00
# 3            20.34  2010-12-01    536365     17850.0        20.34
# 4            20.34  2010-12-01    536365     17850.0        20.34
# ...            ...         ...       ...         ...          ...
# 541904       10.20  2011-12-09    581587     12680.0        10.20
# 541905       12.60  2011-12-09    581587     12680.0        12.60
# 541906       16.60  2011-12-09    581587     12680.0        16.60
# 541907       16.60  2011-12-09    581587     12680.0        16.60
# 541908       14.85  2011-12-09    581587     12680.0        14.85
#
# [541909 rows x 5 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <p style="background-color:dodgerblue;font-family:arial;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Thank you, with the hope that you find it useful.
# </b></p>
#
# <b>If you want to be the first to be informed about new projects, please do not forget to follow me on.. | </b>[Linkedin](https://www.linkedin.com/in/duygujones/) | [Kaggle](https://www.kaggle.com/duygujones) | [Tableau](https://public.tableau.com/app/profile/duygu.jones/vizzes) | [Source]()
