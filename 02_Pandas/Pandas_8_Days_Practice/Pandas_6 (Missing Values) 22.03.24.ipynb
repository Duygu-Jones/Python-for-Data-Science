# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Pandas_InClass_6 (Missing Values)</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <font color='green'> <b>Importing Libraries </b><font color='black'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = sns.load_dataset("diamonds")
df

# %%
df = sns.load_dataset("diamonds")

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df.describe(include="all").T
# Out:
#            count unique    top   freq         mean          std    min    25%  \
# carat    53940.0    NaN    NaN    NaN      0.79794     0.474011    0.2    0.4
# cut        53940      5  Ideal  21551          NaN          NaN    NaN    NaN
# color      53940      7      G  11292          NaN          NaN    NaN    NaN
# clarity    53940      8    SI1  13065          NaN          NaN    NaN    NaN
# depth    53940.0    NaN    NaN    NaN    61.749405     1.432621   43.0   61.0
# table    53940.0    NaN    NaN    NaN    57.457184     2.234491   43.0   56.0
# price    53940.0    NaN    NaN    NaN  3932.799722  3989.439738  326.0  950.0
# x        53940.0    NaN    NaN    NaN     5.731157     1.121761    0.0   4.71
# y        53940.0    NaN    NaN    NaN     5.734526     1.142135    0.0   4.72
# z        53940.0    NaN    NaN    NaN     3.538734     0.705699    0.0   2.91
#
#             50%      75%      max
# carat       0.7     1.04     5.01
# cut         NaN      NaN      NaN
# color       NaN      NaN      NaN
# clarity     NaN      NaN      NaN
# depth      61.8     62.5     79.0
# table      57.0     59.0     95.0
# price    2401.0  5324.25  18823.0
# x           5.7     6.54    10.74
# y          5.71     6.54     58.9
# z          3.53     4.04     31.8

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.groupby("cut")["price"].agg([min, max, np.mean])
# Out:
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The provided callable <function mean at 0x0000020DC2FFF2E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
#            min    max         mean
# cut
# Ideal      326  18806  3457.541970
# Premium    326  18823  4584.257704
# Very Good  336  18818  3981.759891
# Good       327  18788  3928.864452
# Fair       337  18574  4358.757764

# %%
df.groupby("color")["price"].agg([min, max, np.mean])
# Out:
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\365971697.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("color")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\365971697.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby("color")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\365971697.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby("color")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\365971697.py:1: FutureWarning: The provided callable <function mean at 0x0000020DC2FFF2E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("color")["price"].agg([min, max, np.mean])
#        min    max         mean
# color
# D      357  18693  3169.954096
# E      326  18731  3076.752475
# F      342  18791  3724.886397
# G      354  18818  3999.135671
# H      337  18803  4486.669196
# I      334  18823  5091.874954
# J      335  18710  5323.818020

# %%
df.groupby("carat")["price"].agg([min, max, np.mean])
# Out:
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\3659871902.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby("carat")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\3659871902.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby("carat")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\3659871902.py:1: FutureWarning: The provided callable <function mean at 0x0000020DC2FFF2E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("carat")["price"].agg([min, max, np.mean])
#          min    max          mean
# carat
# 0.20     345    367    365.166667
# 0.21     326    394    380.222222
# 0.22     337    470    391.400000
# 0.23     326    688    486.143345
# 0.24     336    963    505.185039
# ...      ...    ...           ...
# 4.00   15984  15984  15984.000000
# 4.01   15223  15223  15223.000000
# 4.13   17329  17329  17329.000000
# 4.50   18531  18531  18531.000000
# 5.01   18018  18018  18018.000000
#
# [273 rows x 3 columns]

# %%
df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).head(25)
# Out:
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\3797320219.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).head(25)
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\3797320219.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).head(25)
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\3797320219.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).head(25)
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\3797320219.py:1: FutureWarning: The provided callable <function mean at 0x0000020DC2FFF2E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).head(25)
#                min    max        mean
# carat color
# 0.20  D      367.0  367.0  367.000000
#       E      345.0  367.0  364.250000
#       F      367.0  367.0  367.000000
#       G        NaN    NaN         NaN
#       H        NaN    NaN         NaN
#       I        NaN    NaN         NaN
#       J        NaN    NaN         NaN
# 0.21  D      386.0  386.0  386.000000
#       E      326.0  394.0  375.600000
#       F        NaN    NaN         NaN
#       G        NaN    NaN         NaN
#       H        NaN    NaN         NaN
#       I        NaN    NaN         NaN
#       J        NaN    NaN         NaN
# 0.22  D      404.0  404.0  404.000000
#       E      337.0  404.0  370.500000
#       F      342.0  470.0  406.000000
#       G        NaN    NaN         NaN
#       H        NaN    NaN         NaN
#       I        NaN    NaN         NaN
#       J        NaN    NaN         NaN
# 0.23  D      357.0  688.0  493.355556
#       E      326.0  682.0  497.133858
#       F      357.0  650.0  493.013158
#       G      354.0  550.0  447.931034

# %%
df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).tail(25)
# Out:
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\115934068.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).tail(25)
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\115934068.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).tail(25)
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\115934068.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).tail(25)
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\115934068.py:1: FutureWarning: The provided callable <function mean at 0x0000020DC2FFF2E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(["carat", "color"])["price"].agg([min, max, np.mean]).tail(25)
#                  min      max     mean
# carat color
# 4.01  G          NaN      NaN      NaN
#       H          NaN      NaN      NaN
#       I      15223.0  15223.0  15223.0
#       J      15223.0  15223.0  15223.0
# 4.13  D          NaN      NaN      NaN
#       E          NaN      NaN      NaN
#       F          NaN      NaN      NaN
#       G          NaN      NaN      NaN
#       H      17329.0  17329.0  17329.0
#       I          NaN      NaN      NaN
#       J          NaN      NaN      NaN
# 4.50  D          NaN      NaN      NaN
#       E          NaN      NaN      NaN
#       F          NaN      NaN      NaN
#       G          NaN      NaN      NaN
#       H          NaN      NaN      NaN
#       I          NaN      NaN      NaN
#       J      18531.0  18531.0  18531.0
# 5.01  D          NaN      NaN      NaN
#       E          NaN      NaN      NaN
#       F          NaN      NaN      NaN
#       G          NaN      NaN      NaN
#       H          NaN      NaN      NaN
#       I          NaN      NaN      NaN
#       J      18018.0  18018.0  18018.0

# %%
df.select_dtypes(include="number").corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.corr()
#
# File c:\Users\Duygu Jones\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Duygu Jones\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\Duygu Jones\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\Duygu Jones\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1709, in BlockManager._interleave(self, dtype, na_value)
#    1703 rl = blk.mgr_locs
#    1704 if blk.is_extension:
#    1705     # Avoid implicit conversion of extension blocks to object
#    1706
#    1707     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1708     # attribute "to_numpy"
# -> 1709     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1710         dtype=dtype,
#    1711         na_value=na_value,
#    1712     )
#    1713 else:
#    1714     arr = blk.get_values(dtype)
#
# File c:\Users\Duygu Jones\anaconda3\Lib\site-packages\pandas\core\arrays\base.py:530, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     501 def to_numpy(
#     502     self,
#     503     dtype: npt.DTypeLike | None = None,
#     504     copy: bool = False,
#     505     na_value: object = lib.no_default,
#     506 ) -> np.ndarray:
#     507     """
#     508     Convert to a NumPy ndarray.
#     509
#    (...)
#     528     numpy.ndarray
#     529     """
# --> 530     result = np.asarray(self, dtype=dtype)
#     531     if copy or na_value is not lib.no_default:
#     532         result = result.copy()
#
# File c:\Users\Duygu Jones\anaconda3\Lib\site-packages\pandas\core\arrays\_mixins.py:80, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      77 @wraps(meth)
#      78 def method(self, *args, **kwargs):
#      79     if self.ndim == 1:
# ---> 80         return meth(self, *args, **kwargs)
#      82     flags = self._ndarray.flags
#      83     flat = self.ravel("K")
#
# File c:\Users\Duygu Jones\anaconda3\Lib\site-packages\pandas\core\arrays\categorical.py:1635, in Categorical.__array__(self, dtype)
#    1633 ret = take_nd(self.categories._values, self._codes)
#    1634 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1635     return np.asarray(ret, dtype)
#    1636 # When we're a Categorical[ExtensionArray], like Interval,
#    1637 # we need to ensure __array__ gets all the way to an
#    1638 # ndarray.
#    1639 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'Ideal'

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.groupby("cut")["price"].agg([min, max, np.mean])
# Out:
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
# C:\Users\Duygu Jones\AppData\Local\Temp\ipykernel_14276\881942075.py:1: FutureWarning: The provided callable <function mean at 0x0000020DC2FFF2E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("cut")["price"].agg([min, max, np.mean])
#            min    max         mean
# cut
# Ideal      326  18806  3457.541970
# Premium    326  18823  4584.257704
# Very Good  336  18818  3981.759891
# Good       327  18788  3928.864452
# Fair       337  18574  4358.757764

# %%
df.cut.map({"Ideal": 0, "Premium":1, "Good":2, "Very Good":3, "Fair": 4})
# Out:
# 0        0
# 1        1
# 2        2
# 3        1
# 4        2
#         ..
# 53935    0
# 53936    2
# 53937    3
# 53938    1
# 53939    0
# Name: cut, Length: 53940, dtype: category
# Categories (5, int64): [0, 1, 3, 2, 4]

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.groupby(["cut", "color"])[["price"]].count().sort_values(by="price")
# Out:
#                  price
# cut       color
# Fair      J        119
#           D        163
#           I        175
#           E        224
#           H        303
# Good      J        307
# Fair      F        312
#           G        314
# Good      I        522
#           D        662
# Very Good J        678
# Good      H        702
# Premium   J        808
# Good      G        871
# Ideal     J        896
# Good      F        909
#           E        933
# Very Good I       1204
# Premium   I       1428
# Very Good D       1513
# Premium   D       1603
# Very Good H       1824
# Ideal     I       2093
# Very Good F       2164
#           G       2299
# Premium   F       2331
#           E       2337
#           H       2360
# Very Good E       2400
# Ideal     D       2834
# Premium   G       2924
# Ideal     H       3115
#           F       3826
#           E       3903
#           G       4884

# %% [markdown]
# # <font color='green'> <b>Missing Values</b><font color='black'>

# %% [markdown]
# ## <font color='green'> <b>Type of NaN Values</b><font color='white'>
#
# [SOURCE01](https://www.educative.io/edpresso/what-is-the-none-keyword-in-python),
# [SOURCE02](https://stackoverflow.com/questions/21095654/what-is-a-nonetype-object),
# [SOURCE03](https://www.skytowner.com/explore/difference_between_none_and_nan_in_pandas),
# [SOURCE04](https://kegui.medium.com/what-is-the-difference-between-nan-none-pd-nan-and-np-nan-a8ee0532e2eb),
# [SOURCE05](https://stackoverflow.com/questions/53436339/difference-between-np-nan-and-np-nan),
# [SOURCE06](https://stackoverflow.com/questions/40309789/difference-between-nan-and-nan-in-python),
# [SOURCE07](https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b)
#
# **None**:
#    - Python'da "hiçbir şey" anlamına gelir.
#    - Python'da bir nesnenin değeri olmadığını göstermek için kullanılır.
#    - Tipi NoneType'dır ve sadece tek bir değeri vardır: None.
#    - Örneğin, bir fonksiyonun herhangi bir değer döndürmemesi durumunda, Python otomatik olarak None döndürür.
#
# **nan ve NaN**:
#    - "Not a Number" ifadesinin kısaltmasıdır.
#    - float tipinde bir değeri temsil eder.
#    - Sayısal olmayan değerleri göstermek için kullanılır.
#    - Pandas ve Numpy gibi kütüphanelerde, kayıp veriyi (missing data) temsil etmek için de kullanılır.
#    - nan değerleri eşitlikle karşılaştırıldığında her zaman False döndürür. Yani, nan == nan ifadesi False sonucunu verir.
#    - nan ve NaN arasında teknik bir fark yoktur. Farklı kaynaklarda veya kütüphanelerde farklı yazım biçimleri tercih edilir, ancak ikisi de aynı anlama gelir.
#
# **Özetle**:
# - None Python'ın özgün bir değeridir ve "değer yok" anlamına gelir.
# - nan veya NaN sayısal olmayan değerleri temsil eder ve genellikle kayıp veri veya matematiksel olarak tanımlanmayan işlemler için kullanılır.
#
# Bu iki değer farklı tiplere aittir ve farklı durumlar için kullanılır.
#
# Uygulamada, veri analizi yaparken Pandas'ta sıkça NaN değerleriyle karşılaşırsınız. Ancak genel Python programlamasında None daha yaygındır.

# %%
id_no = ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010", "P011"]
gender = ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"]
status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]
dept = ["DS", "FS", "AWS", "AWS", "DS", None, "FS", "FS", np.nan, "DS", "AWS"]
V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])
V2 = np.array([8, np.nan, 5, 8, 11, np.nan, np.nan, 2, 3, 7, 9])
salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])

df0 = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })

# %%
df = df0.copy()

# %%
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 748.0+ bytes

# %%
type(np.nan)
# Out:
# float

# %%
type(np.NaN)
# Out:
# float

# %%
type(pd.nan)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 type(pd.nan)
#
# AttributeError: module 'pandas' has no attribute 'nan'

# %%
type(None)
# Out:
# NoneType

# %%
pd.Series([1,np.nan, np.NaN, 2, None])
# Out:
# 0    1.0
# 1    NaN
# 2    NaN
# 3    2.0
# 4    NaN
# dtype: float64

# %%
print("1", 0 * np.nan)
print("2", np.nan - np.nan)
print("3", np.nan + np.nan)
print("4", np.nan - 10)
print("5", np.nan + 10)
print("6", np.nan == np.nan) # değer olarak eşit değil. çünkü belirsiz.
print("7", 10 > np.nan)
print("8", np.inf > np.nan) # değeri belirsiz olduğu için
                    # sonsuz > nan diye sorguladığımızda bile false veriyor
print("9", float('-inf') < np.nan < float('inf')) # nan, eksi sonsuz ile artı sonsuz arasına düşen bir değer de değildir.
print("10", np.nan is np.nan) # is ile sorgulama yaptığınızda id değerlerini yani;
# memory location'ını sorgulamış olursunuz ki bu değerler aynıdır.
# Fakat bu; value'ları aynı demek değildir.
# Out:
# 1 nan
# 2 nan
# 3 nan
# 4 nan
# 5 nan
# 6 False
# 7 False
# 8 False
# 9 False
# 10 True

# %% [markdown]
# ## <font color='blue'> <b>Detecting Missing Values</b><font color='black'>

# %%
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.isnull()
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.isna()
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.notnull()
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False

# %%
df.notna()
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False

# %%
df.isnull()
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.isnull().any() # herhangi bir satırda null değer var mı diye kontrol eder.
# Out:
# id        False
# gender    False
# status     True
# dept       True
# var1      False
# var2       True
# salary     True
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
df.isnull()
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.isnull().any(axis = 1)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
df[df.isnull().any(axis = 1) ]
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 8   P009      M     PT   NaN   14   3.0     60
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.isnull().sum() # sütünlarda kaçar tane nan değr olduğunu tespit eder.
# Out:
# id        0
# gender    0
# status    1
# dept      2
# var1      0
# var2      3
# salary    3
# dtype: int64

# %%
df.isnull().sum().sum() # tüm dataframede kaç tane nan değer olduğunu tespit eder.
# Out:
# 9

# %%
id_no = ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010", "P011"]
gender = ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"]
status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]
dept = ["DS", "FS", "AWS", "AWS", "DS", None, "FS", "FS", np.nan, "DS", "AWS"]
V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])
V2 = np.array([8, np.nan, 5, 8, 11, np.nan, np.nan, 2, 3, 7, 9])
salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])

df0 = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 748.0+ bytes

# %% [markdown]
# ## <font color='green'> <b>Converting Improper Values to NaN Values</b><font color='black'>

# %%
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df["var1"]
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].replace(to_replace= "-", value=np.nan)
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df["var1"] = df["var1"].replace(to_replace= "-", value=np.nan)

# %%
df["var1"]
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS  NaN   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    10 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 744.0+ bytes

# %%
df["var1"] = df["var1"].astype("float")

# %%
df.var1
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    8 non-null      float64
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 748.0+ bytes

# %%
df["status"] = df["status"].replace(to_replace= "-", value=np.nan)
df["status"]
# Out:
# 0      FT
# 1      PT
# 2     NaN
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7     NaN
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.isnull().sum()
# Out:
# id        0
# gender    0
# status    3
# dept      2
# var1      3
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# ## <font color='green'> <b>Missing Value Handling Methods</b><font color='black'>
#
# [SOURCE01](https://towardsdatascience.com/7-ways-to-handle-missing-values-in-machine-learning-1a6326adf79e),
# [SOURCE02](https://www.shiksha.com/online-courses/articles/handling-missing-values-beginners-tutorial/),
# [SOURCE03](https://medium.com/geekculture/how-to-deal-with-missing-values-in-machine-learning-98e47f025b9c),
# [SOURCE04](https://yigitsener.medium.com/veri-biliminde-eksik-kay%C4%B1p-verilere-yakla%C5%9F%C4%B1m-stratejileri-ve-python-pandas-uygulamas%C4%B1-501fbf643795)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='blue'> <b>dropna() & drop()</b><font color='black'>

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dropna() # içinde nan olan bütün satırları siler.
# Out:
#      id gender status dept  var1  var2 salary
# 4  P005      M     PT   DS   7.0  11.0     58

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dropna(axis = 0, how= "any", inplace=False) # any >> belirtilen axis içinde bir tane bile nan değer varsa siler
# Out:
#      id gender status dept  var1  var2 salary
# 4  P005      M     PT   DS   7.0  11.0     58

# %%
df.dropna(axis = 0, how= "all", inplace=False)  # all >> belirtilen axis içindeki tüm değerler nan ise siler
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dropna(axis = 1, how= "any", inplace=False)
# Out:
#       id gender
# 0   P001      M
# 1   P002      F
# 2   P003      M
# 3   P004      F
# 4   P005      M
# 5   P006      F
# 6   P007      M
# 7   P008      F
# 8   P009      M
# 9   P010      F
# 10  P011      M

# %%
df.dropna(axis = 1, how= "all", inplace=False)
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dropna(axis = 1, thresh= 9, inplace=False)
# Out:
#       id gender  dept
# 0   P001      M    DS
# 1   P002      F    FS
# 2   P003      M   AWS
# 3   P004      F   AWS
# 4   P005      M    DS
# 5   P006      F  None
# 6   P007      M    FS
# 7   P008      F    FS
# 8   P009      M   NaN
# 9   P010      F    DS
# 10  P011      M   AWS

# %%
df.drop() # içine silinmesi istenen satır veya sütünları yazmamaız lazım
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df.drop()
#
# File c:\Users\a\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\a\anaconda3\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
#    4783     errors: str = "raise",
#    4784 ):
#    4785     """
#    4786     Drop specified labels from rows or columns.
#    4787
#    (...)
#    4904             weight  1.0     0.8
#    4905     """
# -> 4906     return super().drop(
#    4907         labels=labels,
#    4908         axis=axis,
#    4909         index=index,
#    4910         columns=columns,
#    4911         level=level,
#    4912         inplace=inplace,
#    4913         errors=errors,
#    4914     )
#
# File c:\Users\a\anaconda3\lib\site-packages\pandas\core\generic.py:4142, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4140     axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    4141 else:
# -> 4142     raise ValueError(
#    4143         "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4144     )
#    4146 obj = self
#    4148 for axis, labels in axes.items():
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.drop([5,6,10])
# Out:
#      id gender status dept  var1  var2 salary
# 0  P001      M     FT   DS   2.0   8.0    NaN
# 1  P002      F     PT   FS   3.0   NaN     54
# 2  P003      M    NaN  AWS   5.0   5.0     59
# 3  P004      F     FT  AWS   NaN   8.0    120
# 4  P005      M     PT   DS   7.0  11.0     58
# 7  P008      F    NaN   FS  10.0   2.0    136
# 8  P009      M     PT  NaN  14.0   3.0     60
# 9  P010      F     FT   DS   NaN   7.0    125

# %%
df.drop(index = [5,6,10])
# Out:
#      id gender status dept  var1  var2 salary
# 0  P001      M     FT   DS   2.0   8.0    NaN
# 1  P002      F     PT   FS   3.0   NaN     54
# 2  P003      M    NaN  AWS   5.0   5.0     59
# 3  P004      F     FT  AWS   NaN   8.0    120
# 4  P005      M     PT   DS   7.0  11.0     58
# 7  P008      F    NaN   FS  10.0   2.0    136
# 8  P009      M     PT  NaN  14.0   3.0     60
# 9  P010      F     FT   DS   NaN   7.0    125

# %%
df.drop("var2", axis = 1)
# Out:
#       id gender status  dept  var1 salary
# 0   P001      M     FT    DS   2.0    NaN
# 1   P002      F     PT    FS   3.0     54
# 2   P003      M    NaN   AWS   5.0     59
# 3   P004      F     FT   AWS   NaN    120
# 4   P005      M     PT    DS   7.0     58
# 5   P006      F     PT  None   1.0     75
# 6   P007      M     FT    FS   NaN   None
# 7   P008      F    NaN    FS  10.0    136
# 8   P009      M     PT   NaN  14.0     60
# 9   P010      F     FT    DS   NaN    125
# 10  P011      M    NaN   AWS   6.0    NaN

# %%
df.drop(["var2", "gender"], axis = 1)
# Out:
#       id status  dept  var1 salary
# 0   P001     FT    DS   2.0    NaN
# 1   P002     PT    FS   3.0     54
# 2   P003    NaN   AWS   5.0     59
# 3   P004     FT   AWS   NaN    120
# 4   P005     PT    DS   7.0     58
# 5   P006     PT  None   1.0     75
# 6   P007     FT    FS   NaN   None
# 7   P008    NaN    FS  10.0    136
# 8   P009     PT   NaN  14.0     60
# 9   P010     FT    DS   NaN    125
# 10  P011    NaN   AWS   6.0    NaN

# %%
df.drop(columns = ["var2", "gender"])
# Out:
#       id status  dept  var1 salary
# 0   P001     FT    DS   2.0    NaN
# 1   P002     PT    FS   3.0     54
# 2   P003    NaN   AWS   5.0     59
# 3   P004     FT   AWS   NaN    120
# 4   P005     PT    DS   7.0     58
# 5   P006     PT  None   1.0     75
# 6   P007     FT    FS   NaN   None
# 7   P008    NaN    FS  10.0    136
# 8   P009     PT   NaN  14.0     60
# 9   P010     FT    DS   NaN    125
# 10  P011    NaN   AWS   6.0    NaN

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Faydalı Olması Temennisiyle Teşekkürler</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
