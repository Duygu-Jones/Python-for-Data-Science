# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Pandas_InClass_7 (Missing Values & Combining Data Frames)</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [LinkedIn](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <font color='green'> <b>Importing Libraries </b><font color='black'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # <font color='green'> <b>Missing Values</b><font color='black'>

# %%
id_no = ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010", "P011"]
gender = ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"]
status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]
dept = ["DS", "FS", "AWS", "AWS", "DS", None, "FS", "FS", np.nan, "DS", "AWS"]
V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])
V2 = np.array([8, np.nan, 5, 8, 11, np.nan, np.nan, 2, 3, 7, 9])
salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])

df0 = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })

# %%
df = df0.copy()       # df0 ın orjinal olarak kalmasını istiyoruz
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df["var1"] = df["var1"].replace(to_replace = "-", value = np.nan).astype("float")

df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["status"] = df["status"].replace("-", np.nan)
df["status"]
# Out:
# 0      FT
# 1      PT
# 2     NaN
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7     NaN
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df.isnull().sum()
# Out:
# id        0
# gender    0
# status    3
# dept      2
# var1      3
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# ## <font color='blue'> <b>Filling Missing Values (Imputation)</b><font color='black'>

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  8 non-null      object
#  3   dept    9 non-null      object
#  4   var1    8 non-null      float64
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 744.0+ bytes

# %% [markdown]
# ### <font color='orange'> <b>Filling Numeric Variables</b><font color='orange'>

# %%
df.fillna(0) # bütün nan değerleri sıfır ile doldurmak istersek bu şekilde kullanılabilir.
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0       0
# 1   P002      F     PT   FS   3.0   0.0      54
# 2   P003      M      0  AWS   5.0   5.0      59
# 3   P004      F     FT  AWS   0.0   8.0     120
# 4   P005      M     PT   DS   7.0  11.0      58
# 5   P006      F     PT    0   1.0   0.0      75
# 6   P007      M     FT   FS   0.0   0.0       0
# 7   P008      F      0   FS  10.0   2.0     136
# 8   P009      M     PT    0  14.0   3.0      60
# 9   P010      F     FT   DS   0.0   7.0     125
# 10  P011      M      0  AWS   6.0   9.0       0

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.var1.fillna(0) # pd.Series iel de fillna yapılabilir.
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      0.0
# 4      7.0
# 5      1.0
# 6      0.0
# 7     10.0
# 8     14.0
# 9      0.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df.var1.mean()
# Out:
# 6.0

# %%
df.var1.fillna(df.var1.mean()) # df.var1 in ortalaması ile df var1 in nan değerlerini doldurduk
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      1.0
# 6      6.0
# 7     10.0
# 8     14.0
# 9      6.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df.var1.sort_values()
# Out:
# 5      1.0
# 0      2.0
# 1      3.0
# 2      5.0
# 10     6.0
# 4      7.0
# 7     10.0
# 8     14.0
# 3      NaN
# 6      NaN
# 9      NaN
# Name: var1, dtype: float64

# %%
df.var1.median()
# Out:
# 5.5

# %%
df.var1.fillna(df.var1.median()) # df.var1 in ortanca(median) değeri ile df var1 in nan değerlerini doldurduk
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      5.5
# 4      7.0
# 5      1.0
# 6      5.5
# 7     10.0
# 8     14.0
# 9      5.5
# 10     6.0
# Name: var1, dtype: float64

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# ### <font color='orange'> <b>Filling Categorical Variables</b><font color='orange'>

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dept.mode()
# Out:
# 0    AWS
# 1     DS
# 2     FS
# dtype: object

# %%
df.dept.mode()[0]
# Out:
# 'AWS'

# %%
df.status.mode()
# Out:
# 0    FT
# 1    PT
# dtype: object

# %%
df.status.mode()[0]
# Out:
# 'FT'

# %%
df.gender.mode()
# Out:
# 0    M
# dtype: object

# %%
df.gender.mode()[0]
# Out:
# 'M'

# %%
df.dept.fillna(df.dept.mode()[0])
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5     AWS
# 6      FS
# 7      FS
# 8     AWS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df.dept
# Out:
# 0       DS
# 1       FS
# 2      AWS
# 3      AWS
# 4       DS
# 5     None
# 6       FS
# 7       FS
# 8      NaN
# 9       DS
# 10     AWS
# Name: dept, dtype: object

# %%
df.dept.fillna(method="bfill") #backward fill. index sırasına göre bir sonraki ile dolar.
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5      FS
# 6      FS
# 7      FS
# 8      DS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df.dept.fillna(method="ffill") #forward fill.  index sırasına göre bir önceki ile dolar.
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5      DS
# 6      FS
# 7      FS
# 8      FS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df.dept.fillna(method="ffill", inplace=True)

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# ### <font color='orange'> <b>Filling by condition & group</b><font color='black'>

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.groupby("status")["salary"].mean()
# Out:
# status
# FT    122.50
# PT     61.75
# Name: salary, dtype: float64

# %%
df.loc[df.salary > 90, "status" ]
# Out:
# 3     FT
# 7    NaN
# 9     FT
# Name: status, dtype: object

# %%
df.loc[df.salary > 90, "status" ].mode()[0]
# Out:
# 'FT'

# %%
df.loc[df.salary <= 90, "status" ]
# Out:
# 1     PT
# 2    NaN
# 4     PT
# 5     PT
# 8     PT
# Name: status, dtype: object

# %%
df.loc[df.salary <= 90, "status" ].mode()[0]
# Out:
# 'PT'

# %%
df.loc[df.salary > 90, "status" ].fillna(df.loc[df.salary > 90, "status" ].mode()[0])
# Out:
# 3    FT
# 7    FT
# 9    FT
# Name: status, dtype: object

# %%
# inplace= True çalışmadı. 
df.loc[df.salary > 90, "status" ].fillna(df.loc[df.salary > 90, "status" ].mode()[0], inplace=True)

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
#inplace çalışamzsa assign etmek gerekir. 
df.loc[df.salary > 90, "status" ] = df.loc[df.salary > 90, "status" ].mode()[0]

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.loc[df.salary <= 90, "status" ] = df.loc[df.salary <= 90, "status" ].mode()[0]

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# **'Status' sütunundaki son eksik değeri 'gender' ve 'dept' grubunun modu ile dolduralım.**

# %%
df.groupby(["gender", "dept"])["status"].transform(lambda x: x.mode()[0])
# Out:
# 0     FT
# 1     FT
# 2     PT
# 3     FT
# 4     FT
# 5     FT
# 6     FT
# 7     FT
# 8     FT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.status.fillna(df.groupby(["gender", "dept"])["status"].transform(lambda x: x.mode()[0]))
# Out:
# 0     FT
# 1     PT
# 2     PT
# 3     FT
# 4     PT
# 5     PT
# 6     FT
# 7     FT
# 8     PT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.var1.mode()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     6.0
# 5     7.0
# 6    10.0
# 7    14.0
# dtype: float64

# %%
df.var1.fillna(df.var1.mode())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      5.0
# 4      7.0
# 5      1.0
# 6     10.0
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df.status.fillna(df.groupby(["gender", "dept"])["status"].transform(lambda x: x.mode()[0]), inplace=True)

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M     PT  AWS   6.0   9.0    NaN

# %%
df.var1.fillna(df.groupby(["gender", "status"])["var1"].transform("mean"), inplace=False)
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3     10.0
# 4      7.0
# 5      1.0
# 6      2.0
# 7     10.0
# 8     14.0
# 9     10.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df.var1.fillna(df.groupby(["gender", "status"])["var1"].transform("mean"), inplace=True)

# %%
df.var2.fillna(df.groupby("status")["var2"].transform("mean"), inplace=False)
# Out:
# 0      8.00
# 1      7.00
# 2      5.00
# 3      8.00
# 4     11.00
# 5      7.00
# 6      6.25
# 7      2.00
# 8      3.00
# 9      7.00
# 10     9.00
# Name: var2, dtype: float64

# %%
df.var2.fillna(df.groupby("status")["var2"].transform("mean"), inplace=True)

# %%
df
# Out:
#       id gender status dept  var1   var2 salary
# 0   P001      M     FT   DS   2.0   8.00    NaN
# 1   P002      F     PT   FS   3.0   7.00     54
# 2   P003      M     PT  AWS   5.0   5.00     59
# 3   P004      F     FT  AWS  10.0   8.00    120
# 4   P005      M     PT   DS   7.0  11.00     58
# 5   P006      F     PT   DS   1.0   7.00     75
# 6   P007      M     FT   FS   2.0   6.25   None
# 7   P008      F     FT   FS  10.0   2.00    136
# 8   P009      M     PT   FS  14.0   3.00     60
# 9   P010      F     FT   DS  10.0   7.00    125
# 10  P011      M     PT  AWS   6.0   9.00    NaN

# %%
df.salary.fillna(df.groupby(["status","dept"])["salary"].transform("mean"), inplace=False)
# Out:
# 0     125.0
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6     136.0
# 7     136.0
# 8      60.0
# 9     125.0
# 10     59.0
# Name: salary, dtype: float64

# %%
df.salary.fillna(df.groupby(["status","dept"])["salary"].transform("mean"), inplace=True)

# %%
df0
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df
# Out:
#       id gender status dept  var1   var2  salary
# 0   P001      M     FT   DS   2.0   8.00   125.0
# 1   P002      F     PT   FS   3.0   7.00    54.0
# 2   P003      M     PT  AWS   5.0   5.00    59.0
# 3   P004      F     FT  AWS  10.0   8.00   120.0
# 4   P005      M     PT   DS   7.0  11.00    58.0
# 5   P006      F     PT   DS   1.0   7.00    75.0
# 6   P007      M     FT   FS   2.0   6.25   136.0
# 7   P008      F     FT   FS  10.0   2.00   136.0
# 8   P009      M     PT   FS  14.0   3.00    60.0
# 9   P010      F     FT   DS  10.0   7.00   125.0
# 10  P011      M     PT  AWS   6.0   9.00    59.0

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Faydalı Olması Temennisiyle Teşekkürler</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [LinkedIn](https://www.linkedin.com/company/techproeducation/mycompany/) |
