# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Pandas_InClass_4 (Pandas_InClass_4 (DataFrames Methods & Indexing & Groupby) 19.03.24)</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <font color='green'> <b>Importing Libraries </b><font color='black'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # <font color='green'> <b>DataFrames </b><font color='black'>

# %% [markdown]
# ## <font color='blue'> <b>Conditional Selection</b><font color='black'>

# %%
np.random.seed(45)

data = np.random.randint(1,100, 20).reshape(5, 4)

df = pd.DataFrame(data, index= range(101,106), columns=["col1","col2","col3","col4"])

df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
df.index = "a b c d e".split()

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df > 50
# Out:
#     col1   col2   col3   col4
# a   True  False  False  False
# b   True   True   True  False
# c   True  False   True  False
# d   True   True   True   True
# e  False  False   True  False

# %%
df[df > 50]
# Out:
#    col1  col2  col3  col4
# a  76.0   NaN   NaN   NaN
# b  96.0  62.0  86.0   NaN
# c  69.0   NaN  66.0   NaN
# d  54.0  58.0  73.0  88.0
# e   NaN   NaN  54.0   NaN

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df["col2"]
# Out:
# a    31
# b    62
# c    16
# d    58
# e     9
# Name: col2, dtype: int32

# %%
df["col2"] > 50
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# Name: col2, dtype: bool

# %%
df[df["col2"] > 50]
# Out:
#    col1  col2  col3  col4
# b    96    62    86    36
# d    54    58    73    88

# %%
import seaborn as sns
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic[titanic["deck"] == "C"]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.00      1      0   71.2833        C  First
# 3           1       1  female  35.00      1      0   53.1000        S  First
# 11          1       1  female  58.00      0      0   26.5500        S  First
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 55          1       1    male    NaN      0      0   35.5000        S  First
# 62          0       1    male  45.00      1      0   83.4750        S  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 110         0       1    male  47.00      0      0   52.0000        S  First
# 137         0       1    male  37.00      1      0   53.1000        S  First
# 151         1       1  female  22.00      1      0   66.6000        S  First
# 177         0       1  female  50.00      0      0   28.7125        C  First
# 224         1       1    male  38.00      1      0   90.0000        S  First
# 230         1       1  female  35.00      1      0   83.4750        S  First
# 245         0       1    male  44.00      2      0   90.0000        Q  First
# 252         0       1    male  62.00      0      0   26.5500        S  First
# 268         1       1  female  58.00      0      1  153.4625        S  First
# 269         1       1  female  35.00      0      0  135.6333        S  First
# 273         0       1    male  37.00      0      1   29.7000        C  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 298         1       1    male    NaN      0      0   30.5000        S  First
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 307         1       1  female  17.00      1      0  108.9000        C  First
# 310         1       1  female  24.00      0      0   83.1583        C  First
# 318         1       1  female  31.00      0      2  164.8667        S  First
# 325         1       1  female  36.00      0      0  135.6333        C  First
# 331         0       1    male  45.50      0      0   28.5000        S  First
# 332         0       1    male  38.00      0      1  153.4625        S  First
# 336         0       1    male  29.00      1      0   66.6000        S  First
# 341         1       1  female  24.00      3      2  263.0000        S  First
# 351         0       1    male    NaN      0      0   35.0000        S  First
# 377         0       1    male  27.00      0      2  211.5000        C  First
# 412         1       1  female  33.00      1      0   90.0000        Q  First
# 430         1       1    male  28.00      0      0   26.5500        S  First
# 438         0       1    male  64.00      1      4  263.0000        S  First
# 449         1       1    male  52.00      0      0   30.5000        S  First
# 452         0       1    male  30.00      0      0   27.7500        C  First
# 453         1       1    male  49.00      1      0   89.1042        C  First
# 486         1       1  female  35.00      1      0   90.0000        S  First
# 492         0       1    male  55.00      0      0   30.5000        S  First
# 498         0       1  female  25.00      1      2  151.5500        S  First
# 505         0       1    male  18.00      1      0  108.9000        C  First
# 527         0       1    male    NaN      0      0  221.7792        S  First
# 544         0       1    male  50.00      1      0  106.4250        C  First
# 550         1       1    male  17.00      0      2  110.8833        C  First
# 571         1       1  female  53.00      2      0   51.4792        S  First
# 581         1       1  female  39.00      1      1  110.8833        C  First
# 609         1       1  female  40.00      0      0  153.4625        S  First
# 669         1       1  female    NaN      1      0   52.0000        S  First
# 698         0       1    male  49.00      1      1  110.8833        C  First
# 700         1       1  female  18.00      1      0  227.5250        C  First
# 710         1       1  female  24.00      0      0   49.5042        C  First
# 711         0       1    male    NaN      0      0   26.5500        S  First
# 712         1       1    male  48.00      1      0   52.0000        S  First
# 716         1       1  female  38.00      0      0  227.5250        C  First
# 741         0       1    male  36.00      1      0   78.8500        S  First
# 839         1       1    male    NaN      0      0   29.7000        C  First
# 849         1       1  female    NaN      1      0   89.1042        C  First
# 879         1       1  female  56.00      0      1   83.1583        C  First
# 889         1       1    male  26.00      0      0   30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# 27     man        True    C  Southampton    no  False
# 55     man        True    C  Southampton   yes   True
# 62     man        True    C  Southampton    no  False
# 88   woman       False    C  Southampton   yes  False
# 110    man        True    C  Southampton    no   True
# 137    man        True    C  Southampton    no  False
# 151  woman       False    C  Southampton   yes  False
# 177  woman       False    C    Cherbourg    no   True
# 224    man        True    C  Southampton   yes  False
# 230  woman       False    C  Southampton   yes  False
# 245    man        True    C   Queenstown    no  False
# 252    man        True    C  Southampton    no   True
# 268  woman       False    C  Southampton   yes  False
# 269  woman       False    C  Southampton   yes   True
# 273    man        True    C    Cherbourg    no  False
# 297  child       False    C  Southampton    no  False
# 298    man        True    C  Southampton   yes   True
# 305  child       False    C  Southampton   yes  False
# 307  woman       False    C    Cherbourg   yes  False
# 310  woman       False    C    Cherbourg   yes   True
# 318  woman       False    C  Southampton   yes  False
# 325  woman       False    C    Cherbourg   yes   True
# 331    man        True    C  Southampton    no   True
# 332    man        True    C  Southampton    no  False
# 336    man        True    C  Southampton    no  False
# 341  woman       False    C  Southampton   yes  False
# 351    man        True    C  Southampton    no   True
# 377    man        True    C    Cherbourg    no  False
# 412  woman       False    C   Queenstown   yes  False
# 430    man        True    C  Southampton   yes   True
# 438    man        True    C  Southampton    no  False
# 449    man        True    C  Southampton   yes   True
# 452    man        True    C    Cherbourg    no   True
# 453    man        True    C    Cherbourg   yes  False
# 486  woman       False    C  Southampton   yes  False
# 492    man        True    C  Southampton    no   True
# 498  woman       False    C  Southampton    no  False
# 505    man        True    C    Cherbourg    no  False
# 527    man        True    C  Southampton    no   True
# 544    man        True    C    Cherbourg    no  False
# 550    man        True    C    Cherbourg   yes  False
# 571  woman       False    C  Southampton   yes  False
# 581  woman       False    C    Cherbourg   yes  False
# 609  woman       False    C  Southampton   yes   True
# 669  woman       False    C  Southampton   yes  False
# 698    man        True    C    Cherbourg    no  False
# 700  woman       False    C    Cherbourg   yes  False
# 710  woman       False    C    Cherbourg   yes   True
# 711    man        True    C  Southampton    no   True
# 712    man        True    C  Southampton   yes  False
# 716  woman       False    C    Cherbourg   yes   True
# 741    man        True    C  Southampton    no  False
# 839    man        True    C    Cherbourg   yes   True
# 849  woman       False    C    Cherbourg   yes  False
# 879  woman       False    C    Cherbourg   yes  False
# 889    man        True    C    Cherbourg   yes   True

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.age > 50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
titanic[titanic.age > 50]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 33          0       2    male  66.0      0      0  10.5000        S  Second
# 54          0       1    male  65.0      0      1  61.9792        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 820         1       1  female  52.0      1      1  93.5000        S   First
# 829         1       1  female  62.0      0      0  80.0000      NaN   First
# 851         0       3    male  74.0      0      0   7.7750        S   Third
# 857         1       1    male  51.0      0      0  26.5500        S   First
# 879         1       1  female  56.0      0      1  83.1583        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# 15   woman       False  NaN  Southampton   yes   True
# 33     man        True  NaN  Southampton    no   True
# 54     man        True    B    Cherbourg    no  False
# ..     ...         ...  ...          ...   ...    ...
# 820  woman       False    B  Southampton   yes  False
# 829  woman       False    B          NaN   yes   True
# 851    man        True  NaN  Southampton    no   True
# 857    man        True    E  Southampton   yes   True
# 879  woman       False    C    Cherbourg   yes  False
#
# [64 rows x 15 columns]

# %%
(titanic.age > 50) & (titanic.survived == 1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic[(titanic.age > 50) & (titanic.survived == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 195         1       1  female  58.0      0      0  146.5208        C   First
# 268         1       1  female  58.0      0      1  153.4625        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 366         1       1  female  60.0      1      0   75.2500        C   First
# 449         1       1    male  52.0      0      0   30.5000        S   First
# 483         1       3  female  63.0      0      0    9.5875        S   Third
# 496         1       1  female  54.0      1      0   78.2667        C   First
# 513         1       1  female  54.0      1      0   59.4000        C   First
# 570         1       2    male  62.0      0      0   10.5000        S  Second
# 571         1       1  female  53.0      2      0   51.4792        S   First
# 587         1       1    male  60.0      1      1   79.2000        C   First
# 591         1       1  female  52.0      1      0   78.2667        C   First
# 630         1       1    male  80.0      0      0   30.0000        S   First
# 647         1       1    male  56.0      0      0   35.5000        C   First
# 765         1       1  female  51.0      1      0   77.9583        S   First
# 774         1       2  female  54.0      1      3   23.0000        S  Second
# 820         1       1  female  52.0      1      1   93.5000        S   First
# 829         1       1  female  62.0      0      0   80.0000      NaN   First
# 857         1       1    male  51.0      0      0   26.5500        S   First
# 879         1       1  female  56.0      0      1   83.1583        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 11   woman       False    C  Southampton   yes   True
# 15   woman       False  NaN  Southampton   yes   True
# 195  woman       False    B    Cherbourg   yes   True
# 268  woman       False    C  Southampton   yes  False
# 275  woman       False    D  Southampton   yes  False
# 366  woman       False    D    Cherbourg   yes  False
# 449    man        True    C  Southampton   yes   True
# 483  woman       False  NaN  Southampton   yes   True
# 496  woman       False    D    Cherbourg   yes  False
# 513  woman       False  NaN    Cherbourg   yes  False
# 570    man        True  NaN  Southampton   yes   True
# 571  woman       False    C  Southampton   yes  False
# 587    man        True    B    Cherbourg   yes  False
# 591  woman       False    D    Cherbourg   yes  False
# 630    man        True    A  Southampton   yes   True
# 647    man        True    A    Cherbourg   yes   True
# 765  woman       False    D  Southampton   yes  False
# 774  woman       False  NaN  Southampton   yes  False
# 820  woman       False    B  Southampton   yes  False
# 829  woman       False    B          NaN   yes   True
# 857    man        True    E  Southampton   yes   True
# 879  woman       False    C    Cherbourg   yes  False

# %%
titanic[(titanic.age > 50) & (titanic.survived == 1)].shape
# Out:
# (22, 15)

# %%
titanic[(titanic.age > 50) | (titanic.survived == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 8    woman       False  NaN  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [384 rows x 15 columns]

# %% [markdown]
# ## <font color='blue'> <b>reset_index() & set_index()</b><font color='black'>

# %% [markdown]
# reset_index(), DataFrame indeksini sıfırlar ve bunun yerine default hali kullanır.
#
# set_index(), DataFrame'in belirtilen bir sütununu veya sütunlarını, DataFrame'in yeni bir indeksi olarak ayarlar.

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.set_index("class", drop=True, inplace=True)

# %%
titanic
# Out:
#         survived     sex   age  sibsp  parch     fare embarked    who  \
# class
# Third          0    male  22.0      1      0   7.2500        S    man
# First          1  female  38.0      1      0  71.2833        C  woman
# Third          1  female  26.0      0      0   7.9250        S  woman
# First          1  female  35.0      1      0  53.1000        S  woman
# Third          0    male  35.0      0      0   8.0500        S    man
# ...          ...     ...   ...    ...    ...      ...      ...    ...
# Second         0    male  27.0      0      0  13.0000        S    man
# First          1  female  19.0      0      0  30.0000        S  woman
# Third          0  female   NaN      1      2  23.4500        S  woman
# First          1    male  26.0      0      0  30.0000        C    man
# Third          0    male  32.0      0      0   7.7500        Q    man
#
#         adult_male deck  embark_town alive  alone
# class
# Third         True  NaN  Southampton    no  False
# First        False    C    Cherbourg   yes  False
# Third        False  NaN  Southampton   yes   True
# First        False    C  Southampton   yes  False
# Third         True  NaN  Southampton    no   True
# ...            ...  ...          ...   ...    ...
# Second        True  NaN  Southampton    no   True
# First        False    B  Southampton   yes   True
# Third        False  NaN  Southampton    no  False
# First         True    C    Cherbourg   yes   True
# Third         True  NaN   Queenstown    no   True
#
# [891 rows x 13 columns]

# %%
titanic.set_index("pclass", drop=False)
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked  \
# pclass
# 3              0       3    male  22.0      1      0   7.2500        S
# 1              1       1  female  38.0      1      0  71.2833        C
# 3              1       3  female  26.0      0      0   7.9250        S
# 1              1       1  female  35.0      1      0  53.1000        S
# 3              0       3    male  35.0      0      0   8.0500        S
# ...          ...     ...     ...   ...    ...    ...      ...      ...
# 2              0       2    male  27.0      0      0  13.0000        S
# 1              1       1  female  19.0      0      0  30.0000        S
# 3              0       3  female   NaN      1      2  23.4500        S
# 1              1       1    male  26.0      0      0  30.0000        C
# 3              0       3    male  32.0      0      0   7.7500        Q
#
#          class    who  adult_male deck  embark_town alive  alone
# pclass
# 3        Third    man        True  NaN  Southampton    no  False
# 1        First  woman       False    C    Cherbourg   yes  False
# 3        Third  woman       False  NaN  Southampton   yes   True
# 1        First  woman       False    C  Southampton   yes  False
# 3        Third    man        True  NaN  Southampton    no   True
# ...        ...    ...         ...  ...          ...   ...    ...
# 2       Second    man        True  NaN  Southampton    no   True
# 1        First  woman       False    B  Southampton   yes   True
# 3        Third  woman       False  NaN  Southampton    no  False
# 1        First    man        True    C    Cherbourg   yes   True
# 3        Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.set_index("pclass", inplace=True)

# %%
titanic
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN  Southampton    no  False
# 1            False    C    Cherbourg   yes  False
# 3            False  NaN  Southampton   yes   True
# 1            False    C  Southampton   yes  False
# 3             True  NaN  Southampton    no   True
# ...            ...  ...          ...   ...    ...
# 2             True  NaN  Southampton    no   True
# 1            False    B  Southampton   yes   True
# 3            False  NaN  Southampton    no  False
# 1             True    C    Cherbourg   yes   True
# 3             True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic.reset_index()
# Out:
#       class  survived     sex   age  sibsp  parch     fare embarked    who  \
# 0     Third         0    male  22.0      1      0   7.2500        S    man
# 1     First         1  female  38.0      1      0  71.2833        C  woman
# 2     Third         1  female  26.0      0      0   7.9250        S  woman
# 3     First         1  female  35.0      1      0  53.1000        S  woman
# 4     Third         0    male  35.0      0      0   8.0500        S    man
# ..      ...       ...     ...   ...    ...    ...      ...      ...    ...
# 886  Second         0    male  27.0      0      0  13.0000        S    man
# 887   First         1  female  19.0      0      0  30.0000        S  woman
# 888   Third         0  female   NaN      1      2  23.4500        S  woman
# 889   First         1    male  26.0      0      0  30.0000        C    man
# 890   Third         0    male  32.0      0      0   7.7500        Q    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic.reset_index(drop=True)
# Out:
#      survived     sex   age  sibsp  parch     fare embarked    who  \
# 0           0    male  22.0      1      0   7.2500        S    man
# 1           1  female  38.0      1      0  71.2833        C  woman
# 2           1  female  26.0      0      0   7.9250        S  woman
# 3           1  female  35.0      1      0  53.1000        S  woman
# 4           0    male  35.0      0      0   8.0500        S    man
# ..        ...     ...   ...    ...    ...      ...      ...    ...
# 886         0    male  27.0      0      0  13.0000        S    man
# 887         1  female  19.0      0      0  30.0000        S  woman
# 888         0  female   NaN      1      2  23.4500        S  woman
# 889         1    male  26.0      0      0  30.0000        C    man
# 890         0    male  32.0      0      0   7.7500        Q    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 13 columns]

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.dropna() # içinde NaN olan bütün satırları siler.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
titanic.drop([3,100,150,142,888])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# ..     ...         ...  ...          ...   ...    ...
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [886 rows x 15 columns]

# %%
titanic.drop([3,100,150,142,888], inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# ..     ...         ...  ...          ...   ...    ...
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [886 rows x 15 columns]

# %%
titanic.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        4         0       3    male  35.0      0      0   8.0500        S
# 4        5         0       3    male   NaN      0      0   8.4583        Q
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 881    885         0       3  female  39.0      0      5  29.1250        Q
# 882    886         0       2    male  27.0      0      0  13.0000        S
# 883    887         1       1  female  19.0      0      0  30.0000        S
# 884    889         1       1    male  26.0      0      0  30.0000        C
# 885    890         0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 0     Third    man        True  NaN  Southampton    no  False
# 1     First  woman       False    C    Cherbourg   yes  False
# 2     Third  woman       False  NaN  Southampton   yes   True
# 3     Third    man        True  NaN  Southampton    no   True
# 4     Third    man        True  NaN   Queenstown    no   True
# ..      ...    ...         ...  ...          ...   ...    ...
# 881   Third  woman       False  NaN   Queenstown    no  False
# 882  Second    man        True  NaN  Southampton    no   True
# 883   First  woman       False    B  Southampton   yes   True
# 884   First    man        True    C    Cherbourg   yes   True
# 885   Third    man        True  NaN   Queenstown    no   True
#
# [886 rows x 16 columns]

# %%
titanic.reset_index(drop=True) #drop=True index labelın sütün olarak kalmasını engeller.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           0       3    male  35.0      0      0   8.0500        S   Third
# 4           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 881         0       3  female  39.0      0      5  29.1250        Q   Third
# 882         0       2    male  27.0      0      0  13.0000        S  Second
# 883         1       1  female  19.0      0      0  30.0000        S   First
# 884         1       1    male  26.0      0      0  30.0000        C   First
# 885         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3      man        True  NaN  Southampton    no   True
# 4      man        True  NaN   Queenstown    no   True
# ..     ...         ...  ...          ...   ...    ...
# 881  woman       False  NaN   Queenstown    no  False
# 882    man        True  NaN  Southampton    no   True
# 883  woman       False    B  Southampton   yes   True
# 884    man        True    C    Cherbourg   yes   True
# 885    man        True  NaN   Queenstown    no   True
#
# [886 rows x 15 columns]

# %%
#---------------------------------------------------------------------------------------------------
# titanic datasetine gore groupby agg methodlarini pratik etmek icin sorular olusturup cevaplarini verebilir misin?

# %% [markdown]
# # <font color='green'> <b>Groupby & Aggregation Methods (aggregate() & agg())</b><font color='white'>
#
# groupby(); bir veri setindeki belirli bir sütuna göre gruplama yapmak için kullanılır.
#
# Bu işlev, verileri gruplara ayırmak ve bu gruplar üzerinde çeşitli işlemler yapmak için kullanılır.
#
# Örneğin, bir veri kümesinde müşterilerin isimleri, yaşları ve satın aldıkları ürünler yer alıyor olabilir. groupby() işlevi kullanarak, müşterilerin satın aldıkları ürüne göre gruplandırabilir ve her ürün için ortalama yaşlarını bulabilirsiniz.
#
# [Source01](https://towardsdatascience.com/all-pandas-groupby-you-should-know-for-grouping-data-and-performing-operations-2a8ec1327b5),
# [Source02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html),
# [Source03](https://naomi-fridman.medium.com/pandas-groupby-explained-with-titanic-6a1c47eb8182)
# Pandas'ın aggregation yöntemleri, belirli bir veri kümesi üzerinde işlemler gerçekleştirerek bir sonuç döndürür.
#
# Bu yöntemler, bir veri kümesindeki değerleri toplama, ortalama alma, en büyük veya en küçük değeri bulma gibi farklı işlemleri gerçekleştirir.
#
#
# Pandas'ın aggregation yöntemlerinden bazıları şunlardır:
#
# **sum():** Belirtilen sütunda yer alan tüm değerlerin toplamını döndürür.
#
# **mean():** Belirtilen sütunda yer alan tüm değerlerin ortalamasını döndürür.
#
# **median():** Gruplanmış verilerin medyanını hesaplar.
#
# **mode()** Belirtilen sütunda en çok tekrar eden değerleri döndürür.
#
# **max():** Belirtilen sütunda yer alan en büyük değeri döndürür.
#
# **min():** Belirtilen sütunda yer alan en küçük değeri döndürür.
#
# **count():** Belirtilen sütunda yer alan toplam değer sayısını döndürür.
#
# **std():** Belirtilen sütunda yer alan değerlerin standart sapmasını döndürür.
#
# **var():** Belirtilen sütunda yer alan değerlerin varyansını döndürür.
#
# **describe():** Gruplanmış verilerin istatistiksel özetini hesaplar.
#
# **idxmin():** Belirtilen eksen boyunca minimum değeri içeren ilk indeksi döndürür.
#
# **idxmax():** Belirtilen eksen boyunca maksimum değeri içeren ilk indeksi döndürür.
#
# **corr():** Sütunlar  arasındaki korelasyonu, NA/null değerleri hariç tutarak hesaplar.
#
# Bu yöntemler, bir DataFrame veya Series üzerinde kullanılabilir ve istenilen sütun veya satırlarda işlem yapılabilir.
#
# Pandas'ın aggregation yöntemleri, verileri hızlı ve etkili bir şekilde analiz etmek için çok kullanışlıdır.
#
# [Pandas Official Documentation](https://pandas.pydata.org/docs/reference/frame.html)
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Belirli bir sütuna veya sütunlara göre gruplandırılmış bir veri kümesinde farklı işlevlerin (örneğin, mean, sum, max) uygulanması için kullanılır.
#
# [aggregate](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.aggregate.html),
# [agg](https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.core.groupby.DataFrameGroupBy.agg.html),
# [SOURCE01](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/),
# [SOURCE02](https://www.analyticsvidhya.com/blog/2020/03/groupby-pandas-aggregating-data-python/)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
titanic.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.903101
# male      30.681792
# Name: age, dtype: float64

# %%
titanic.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    84.299128
# 2    20.706649
# 3    13.662908
# Name: fare, dtype: float64

# %%
titanic.groupby("sex")["age"].min()
# Out:
# sex
# female    0.75
# male      0.42
# Name: age, dtype: float64

# %%
titanic.groupby("sex")["age"].max()
# Out:
# sex
# female    63.0
# male      80.0
# Name: age, dtype: float64

# %%
titanic.groupby("sex")["age"].agg([min, max, np.mean])
# Out:
#          min   max       mean
# sex
# female  0.75  63.0  27.903101
# male    0.42  80.0  30.681792

# %%
titanic.groupby("sex")["survived"].count()
# Out:
# sex
# female    310
# male      576
# Name: survived, dtype: int64

# %%
titanic.groupby(["sex", "survived" ]).count()
# Out:
#                  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex    survived
# female 0             79   63     79     79    79        79     79   79
#        1            231  195    231    231   231       229    231  231
# male   0            467  359    467    467   467       467    467  467
#        1            109   93    109    109   109       109    109  109
#
#                  adult_male  deck  embark_town  alive  alone
# sex    survived
# female 0                 79     6           79     79     79
#        1                231    90          229    231    231
# male   0                467    61          467    467    467
#        1                109    45          109    109    109

# %%
titanic.groupby(["sex", "survived" ]).mean()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_15740\3506610039.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic.groupby(["sex", "survived" ]).mean()
#                    pclass        age     sibsp     parch       fare  \
# sex    survived
# female 0         2.848101  25.000000  1.227848  1.037975  23.210499
#        1         1.917749  28.841026  0.510823  0.519481  52.089773
# male   0         2.477516  31.564067  0.441113  0.207709  21.981199
#        1         2.018349  27.276022  0.385321  0.357798  40.821484
#
#                  adult_male     alone
# sex    survived
# female 0           0.000000  0.329114
#        1           0.000000  0.428571
# male   0           0.959315  0.740899
#        1           0.807339  0.587156

# %%
titanic.groupby(["sex", "survived" ])["survived"].count() # önce cinsiyet sonra hayatta kalanalra göre gruplama yaptı.
# Out:
# sex     survived
# female  0            79
#         1           231
# male    0           467
#         1           109
# Name: survived, dtype: int64

# %%
import pandas as pd
# Out:
# c:\Users\a\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pd.__version__
# Out:
# '2.2.1'

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.groupby(["sex", "survived" ])["survived"].count()
# Out:
# sex     survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: survived, dtype: int64

# %%
titanic.groupby(["sex", "survived" ])[["survived"]].count()
# Out:
#                  survived
# sex    survived
# female 0               81
#        1              233
# male   0              468
#        1              109

# %%
titanic.groupby(["sex", "pclass", "survived"])[["survived"]].count()
# Out:
#                         survived
# sex    pclass survived
# female 1      0                3
#               1               91
#        2      0                6
#               1               70
#        3      0               72
#               1               72
# male   1      0               77
#               1               45
#        2      0               91
#               1               17
#        3      0              300
#               1               47

# %%
titanic.groupby(["sex", "pclass"])[["survived"]].value_counts(normalize=True) * 100
# Out:
# sex     pclass  survived
# female  1       1           96.808511
#                 0            3.191489
#         2       1           92.105263
#                 0            7.894737
#         3       0           50.000000
#                 1           50.000000
# male    1       0           63.114754
#                 1           36.885246
#         2       0           84.259259
#                 1           15.740741
#         3       0           86.455331
#                 1           13.544669
# Name: proportion, dtype: float64

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Faydalı Olması Temennisiyle Teşekkürler</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
